# %% [markdown]
# # init
# importing libs

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans
from sklearn.cluster import DBSCAN
from sklearn.decomposition import PCA
from sklearn.naive_bayes import GaussianNB
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import (
    confusion_matrix,
    classification_report,
    f1_score,
    precision_score,
    recall_score,
)

# %% [markdown]
# # Reading_cvs

# %%
df = pd.read_csv('../data/athletes_sport_details.csv')
country_df = pd.read_csv('../data/country_ranks.csv')
df.head()
# Out:
#    ID                      Name Sex   Age  Height  Weight         Team  NOC  \
# 0   1                 A Dijiang   M  24.0   180.0    80.0        China  CHN
# 1   2                  A Lamusi   M  23.0   170.0    60.0        China  CHN
# 2   3       Gunnar Nielsen Aaby   M  24.0   191.0    85.0      Denmark  DEN
# 3   5  Christine Jacoba Aaftink   F  21.0   185.0    82.0  Netherlands  NED
# 4   5  Christine Jacoba Aaftink   F  21.0   185.0    82.0  Netherlands  NED
#
#          Games  Year  Season       City          Sport  \
# 0  1992 Summer  1992  Summer  Barcelona     Basketball
# 1  2012 Summer  2012  Summer     London           Judo
# 2  1920 Summer  1920  Summer  Antwerpen       Football
# 3  1988 Winter  1988  Winter    Calgary  Speed Skating
# 4  1988 Winter  1988  Winter    Calgary  Speed Skating
#
#                                 Event Medal  Sport_Rank  Has_Previous_Medal
# 0         Basketball Men's Basketball   NaN           4               False
# 1        Judo Men's Extra-Lightweight   NaN          18               False
# 2             Football Men's Football   NaN          12               False
# 3    Speed Skating Women's 500 metres   NaN          20               False
# 4  Speed Skating Women's 1,000 metres   NaN          20               False

# %% [markdown]
# # data selection and preprocessing

# %%
Gymnastics_df = df[
    (df['Sport'] == 'Gymnastics') &
    (df['Event'].isin([
        "Gymnastics Women's Individual All-Around",
        "Gymnastics Men's Individual All-Around"
    ]))
]

Gymnastics_df.head() , Gymnastics_df.describe()
# Out:
# (      ID                     Name Sex   Age  Height  Weight          Team  \
#  32    17  Paavo Johannes Aaltonen   M  28.0   175.0    64.0       Finland
#  40    17  Paavo Johannes Aaltonen   M  32.0   175.0    64.0       Finland
#  107   51        Nstor Abad Sanjun   M  23.0   167.0    64.0         Spain
#  298  244         Raouf Abdelraouf   M  22.0   167.0    63.0         Egypt
#  474  394               Irene Abel   F  19.0   160.0    48.0  East Germany
#
#       NOC        Games  Year  Season            City       Sport  \
#  32   FIN  1948 Summer  1948  Summer          London  Gymnastics
#  40   FIN  1952 Summer  1952  Summer        Helsinki  Gymnastics
#  107  ESP  2016 Summer  2016  Summer  Rio de Janeiro  Gymnastics
#  298  EGY  2000 Summer  2000  Summer          Sydney  Gymnastics
#  474  GDR  1972 Summer  1972  Summer          Munich  Gymnastics
#
#                                          Event   Medal  Sport_Rank  \
#  32     Gymnastics Men's Individual All-Around  Bronze          14
#  40     Gymnastics Men's Individual All-Around     NaN          14
#  107    Gymnastics Men's Individual All-Around     NaN          14
#  298    Gymnastics Men's Individual All-Around     NaN          14
#  474  Gymnastics Women's Individual All-Around     NaN          14
#
#       Has_Previous_Medal
#  32                False
#  40                 True
#  107               False
#  298               False
#  474               False  ,
#                    ID          Age       Height       Weight         Year  \
#  count    2736.000000  2736.000000  2736.000000  2736.000000  2736.000000
#  mean    69330.789108    21.305556   161.986842    55.738304  1983.560673
#  std     38656.577903     4.345102     8.477770    10.028718    18.977789
#  min        17.000000    13.000000   127.000000    25.000000  1900.000000
#  25%     36550.750000    18.000000   157.000000    48.000000  1968.000000
#  50%     69067.500000    21.000000   163.000000    57.000000  1984.000000
#  75%    102898.000000    24.000000   168.000000    64.000000  2000.000000
#  max    135379.000000    44.000000   185.000000    87.000000  2016.000000
#
#         Sport_Rank
#  count      2736.0
#  mean         14.0
#  std           0.0
#  min          14.0
#  25%          14.0
#  50%          14.0
#  75%          14.0
#  max          14.0  )

# %%
Gymnastics_df_5000_sample = Gymnastics_df[Gymnastics_df["Year"] >= 2000]
Gymnastics_df_5000_sample
# Out:
#             ID                           Name Sex   Age  Height  Weight  \
# 107         51              Nstor Abad Sanjun   M  23.0   167.0    64.0
# 298        244               Raouf Abdelraouf   M  22.0   167.0    63.0
# 485        396                     Katja Abel   F  25.0   165.0    55.0
# 823        627       Andreea Roxana Acatrinei   F  16.0   150.0    40.0
# 1311       976         Jonna Eva-Maj Adlerteg   F  17.0   153.0    38.0
# ...        ...                            ...  ..   ...     ...     ...
# 205061  134974  Nataliya Kamilovna Ziganshina   F  18.0   156.0    47.0
# 205517  135228            Epke Jan Zonderland   M  22.0   173.0    69.0
# 205600  135269                        Zou Kai   M  20.0   158.0    55.0
# 205645  135291   Roman Volodymyrovych Zozulia   M  21.0   164.0    59.0
# 205653  135291   Roman Volodymyrovych Zozulia   M  25.0   164.0    59.0
#
#                Team  NOC        Games  Year  Season            City  \
# 107           Spain  ESP  2016 Summer  2016  Summer  Rio de Janeiro
# 298           Egypt  EGY  2000 Summer  2000  Summer          Sydney
# 485         Germany  GER  2008 Summer  2008  Summer         Beijing
# 823         Romania  ROU  2008 Summer  2008  Summer         Beijing
# 1311         Sweden  SWE  2012 Summer  2012  Summer          London
# ...             ...  ...          ...   ...     ...             ...
# 205061       Russia  RUS  2004 Summer  2004  Summer          Athina
# 205517  Netherlands  NED  2008 Summer  2008  Summer         Beijing
# 205600        China  CHN  2008 Summer  2008  Summer         Beijing
# 205645      Ukraine  UKR  2000 Summer  2000  Summer          Sydney
# 205653      Ukraine  UKR  2004 Summer  2004  Summer          Athina
#
#              Sport                                     Event Medal  \
# 107     Gymnastics    Gymnastics Men's Individual All-Around   NaN
# 298     Gymnastics    Gymnastics Men's Individual All-Around   NaN
# 485     Gymnastics  Gymnastics Women's Individual All-Around   NaN
# 823     Gymnastics  Gymnastics Women's Individual All-Around   NaN
# 1311    Gymnastics  Gymnastics Women's Individual All-Around   NaN
# ...            ...                                       ...   ...
# 205061  Gymnastics  Gymnastics Women's Individual All-Around   NaN
# 205517  Gymnastics    Gymnastics Men's Individual All-Around   NaN
# 205600  Gymnastics    Gymnastics Men's Individual All-Around   NaN
# 205645  Gymnastics    Gymnastics Men's Individual All-Around   NaN
# 205653  Gymnastics    Gymnastics Men's Individual All-Around   NaN
#
#         Sport_Rank  Has_Previous_Medal
# 107             14               False
# 298             14               False
# 485             14               False
# 823             14               False
# 1311            14               False
# ...            ...                 ...
# 205061          14               False
# 205517          14               False
# 205600          14               False
# 205645          14               False
# 205653          14                True
#
# [777 rows x 17 columns]

# %%
# Dictionary to store the last cumulative count per name
last_count = {}

# Initialize the column
Gymnastics_df_5000_sample['Count'] = 0

# Sort by Name and Year to ensure proper ordering
Gymnastics_df_5000_sample = Gymnastics_df_5000_sample.sort_values(['Name', 'Year']).reset_index(drop=True)

# Iterate through rows
for name, group in Gymnastics_df_5000_sample.groupby('Name', sort=False):
    # Keep track of cumulative count for this name
    count = 0
    for year, year_group in group.groupby('Year', sort=False):
        # Assign the current count to all rows of this year
        indices = year_group.index
        Gymnastics_df_5000_sample.loc[indices, 'Count'] = count
        # Update cumulative count for next year
        count += len(year_group)

Gymnastics_df_5000_sample = Gymnastics_df_5000_sample.sort_values(by='ID').reset_index(drop=True)
Gymnastics_df_5000_sample
# Out:
# C:\Users\aamyr\AppData\Local\Temp\ipykernel_15012\2131119701.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Gymnastics_df_5000_sample['Count'] = 0
#          ID                           Name Sex   Age  Height  Weight  \
# 0        51              Nstor Abad Sanjun   M  23.0   167.0    64.0
# 1       244               Raouf Abdelraouf   M  22.0   167.0    63.0
# 2       396                     Katja Abel   F  25.0   165.0    55.0
# 3       627       Andreea Roxana Acatrinei   F  16.0   150.0    40.0
# 4       976         Jonna Eva-Maj Adlerteg   F  17.0   153.0    38.0
# ..      ...                            ...  ..   ...     ...     ...
# 772  134974  Nataliya Kamilovna Ziganshina   F  18.0   156.0    47.0
# 773  135228            Epke Jan Zonderland   M  22.0   173.0    69.0
# 774  135269                        Zou Kai   M  20.0   158.0    55.0
# 775  135291   Roman Volodymyrovych Zozulia   M  21.0   164.0    59.0
# 776  135291   Roman Volodymyrovych Zozulia   M  25.0   164.0    59.0
#
#             Team  NOC        Games  Year  Season            City       Sport  \
# 0          Spain  ESP  2016 Summer  2016  Summer  Rio de Janeiro  Gymnastics
# 1          Egypt  EGY  2000 Summer  2000  Summer          Sydney  Gymnastics
# 2        Germany  GER  2008 Summer  2008  Summer         Beijing  Gymnastics
# 3        Romania  ROU  2008 Summer  2008  Summer         Beijing  Gymnastics
# 4         Sweden  SWE  2012 Summer  2012  Summer          London  Gymnastics
# ..           ...  ...          ...   ...     ...             ...         ...
# 772       Russia  RUS  2004 Summer  2004  Summer          Athina  Gymnastics
# 773  Netherlands  NED  2008 Summer  2008  Summer         Beijing  Gymnastics
# 774        China  CHN  2008 Summer  2008  Summer         Beijing  Gymnastics
# 775      Ukraine  UKR  2000 Summer  2000  Summer          Sydney  Gymnastics
# 776      Ukraine  UKR  2004 Summer  2004  Summer          Athina  Gymnastics
#
#                                         Event Medal  Sport_Rank  \
# 0      Gymnastics Men's Individual All-Around   NaN          14
# 1      Gymnastics Men's Individual All-Around   NaN          14
# 2    Gymnastics Women's Individual All-Around   NaN          14
# 3    Gymnastics Women's Individual All-Around   NaN          14
# 4    Gymnastics Women's Individual All-Around   NaN          14
# ..                                        ...   ...         ...
# 772  Gymnastics Women's Individual All-Around   NaN          14
# 773    Gymnastics Men's Individual All-Around   NaN          14
# 774    Gymnastics Men's Individual All-Around   NaN          14
# 775    Gymnastics Men's Individual All-Around   NaN          14
# 776    Gymnastics Men's Individual All-Around   NaN          14
#
#      Has_Previous_Medal  Count
# 0                 False      0
# 1                 False      0
# 2                 False      0
# 3                 False      0
# 4                 False      0
# ..                  ...    ...
# 772               False      0
# 773               False      0
# 774               False      0
# 775               False      0
# 776                True      1
#
# [777 rows x 18 columns]

# %% [markdown]
# making ranking for every country based on economy and technology

# %%
x=Gymnastics_df_5000_sample["Team"].unique()
len(x)
# Out:
# 73

# %%
result = pd.merge(Gymnastics_df_5000_sample, country_df, how="left", on=["Team"])
result = result.drop(columns=["Sport_Rank","Year"])
Gymnastics_df_5000_sample = result[["ID","Name","Sex","Age","Height","Weight","Team","Development_Status","Rank","NOC","Games","Season","City","Sport","Event","Has_Previous_Medal","Count","Medal"]]

# %%
Gymnastics_df_5000_sample = Gymnastics_df_5000_sample.dropna(subset=["Development_Status", "Rank"])
Gymnastics_df_5000_sample["ID"] = range(1, len(Gymnastics_df_5000_sample) + 1)
Gymnastics_df_5000_sample.to_csv('../data/Gymnastics_sample.csv')
Gymnastics_df_5000_sample
# Out:
#       ID                           Name Sex   Age  Height  Weight  \
# 0      1              Nstor Abad Sanjun   M  23.0   167.0    64.0
# 1      2               Raouf Abdelraouf   M  22.0   167.0    63.0
# 2      3                     Katja Abel   F  25.0   165.0    55.0
# 3      4       Andreea Roxana Acatrinei   F  16.0   150.0    40.0
# 4      5         Jonna Eva-Maj Adlerteg   F  17.0   153.0    38.0
# ..   ...                            ...  ..   ...     ...     ...
# 772  773  Nataliya Kamilovna Ziganshina   F  18.0   156.0    47.0
# 773  774            Epke Jan Zonderland   M  22.0   173.0    69.0
# 774  775                        Zou Kai   M  20.0   158.0    55.0
# 775  776   Roman Volodymyrovych Zozulia   M  21.0   164.0    59.0
# 776  777   Roman Volodymyrovych Zozulia   M  25.0   164.0    59.0
#
#             Team Development_Status  Rank  NOC        Games  Season  \
# 0          Spain          Developed     1  ESP  2016 Summer  Summer
# 1          Egypt         Developing     3  EGY  2000 Summer  Summer
# 2        Germany          Developed     1  GER  2008 Summer  Summer
# 3        Romania          Developed     1  ROU  2008 Summer  Summer
# 4         Sweden          Developed     1  SWE  2012 Summer  Summer
# ..           ...                ...   ...  ...          ...     ...
# 772       Russia       Upper-Middle     2  RUS  2004 Summer  Summer
# 773  Netherlands          Developed     1  NED  2008 Summer  Summer
# 774        China       Upper-Middle     2  CHN  2008 Summer  Summer
# 775      Ukraine         Developing     3  UKR  2000 Summer  Summer
# 776      Ukraine         Developing     3  UKR  2004 Summer  Summer
#
#                City       Sport                                     Event  \
# 0    Rio de Janeiro  Gymnastics    Gymnastics Men's Individual All-Around
# 1            Sydney  Gymnastics    Gymnastics Men's Individual All-Around
# 2           Beijing  Gymnastics  Gymnastics Women's Individual All-Around
# 3           Beijing  Gymnastics  Gymnastics Women's Individual All-Around
# 4            London  Gymnastics  Gymnastics Women's Individual All-Around
# ..              ...         ...                                       ...
# 772          Athina  Gymnastics  Gymnastics Women's Individual All-Around
# 773         Beijing  Gymnastics    Gymnastics Men's Individual All-Around
# 774         Beijing  Gymnastics    Gymnastics Men's Individual All-Around
# 775          Sydney  Gymnastics    Gymnastics Men's Individual All-Around
# 776          Athina  Gymnastics    Gymnastics Men's Individual All-Around
#
#      Has_Previous_Medal  Count Medal
# 0                 False      0   NaN
# 1                 False      0   NaN
# 2                 False      0   NaN
# 3                 False      0   NaN
# 4                 False      0   NaN
# ..                  ...    ...   ...
# 772               False      0   NaN
# 773               False      0   NaN
# 774               False      0   NaN
# 775               False      0   NaN
# 776                True      1   NaN
#
# [777 rows x 18 columns]

# %% [markdown]
# - we gather some data now lets shift to other processes
# - endcoding

# %%
Gymnastics_df_5000_sample["Sex"] = Gymnastics_df_5000_sample["Sex"].map({"M": 0, "F": 1})
Gymnastics_df_5000_sample["Has_Previous_Medal"] = Gymnastics_df_5000_sample["Has_Previous_Medal"].map({False: 0, True: 1})
Gymnastics_df_5000_sample["Rank"] = Gymnastics_df_5000_sample["Development_Status"].map({
    "Developed": 3,
    "Upper-Middle": 2,
    "Developing": 1
})

# %%
Gymnastics_df_5000_sample.head()
# Out:
#    ID                      Name  Sex   Age  Height  Weight     Team  \
# 0   1         Nstor Abad Sanjun    0  23.0   167.0    64.0    Spain
# 1   2          Raouf Abdelraouf    0  22.0   167.0    63.0    Egypt
# 2   3                Katja Abel    1  25.0   165.0    55.0  Germany
# 3   4  Andreea Roxana Acatrinei    1  16.0   150.0    40.0  Romania
# 4   5    Jonna Eva-Maj Adlerteg    1  17.0   153.0    38.0   Sweden
#
#   Development_Status  Rank  NOC        Games  Season            City  \
# 0          Developed     3  ESP  2016 Summer  Summer  Rio de Janeiro
# 1         Developing     1  EGY  2000 Summer  Summer          Sydney
# 2          Developed     3  GER  2008 Summer  Summer         Beijing
# 3          Developed     3  ROU  2008 Summer  Summer         Beijing
# 4          Developed     3  SWE  2012 Summer  Summer          London
#
#         Sport                                     Event  Has_Previous_Medal  \
# 0  Gymnastics    Gymnastics Men's Individual All-Around                   0
# 1  Gymnastics    Gymnastics Men's Individual All-Around                   0
# 2  Gymnastics  Gymnastics Women's Individual All-Around                   0
# 3  Gymnastics  Gymnastics Women's Individual All-Around                   0
# 4  Gymnastics  Gymnastics Women's Individual All-Around                   0
#
#    Count Medal
# 0      0   NaN
# 1      0   NaN
# 2      0   NaN
# 3      0   NaN
# 4      0   NaN

# %% [markdown]
# - i use Z-score formula for standardizition (scaling)
# - x′=(x−μ)/σ

# %%
num_cols = ["Age", "Height", "Weight","Count","Rank","Has_Previous_Medal"]
for col in num_cols:
    mean = Gymnastics_df_5000_sample[col].mean()
    std = Gymnastics_df_5000_sample[col].std()
    Gymnastics_df_5000_sample[col] = (Gymnastics_df_5000_sample[col] - mean) / std
Gymnastics_df_5000_sample = Gymnastics_df_5000_sample.drop(columns=["ID"])
Gymnastics_df_5000_sample.to_csv('../data/Scaled_gymnastics_sample.csv')
Gymnastics_df_5000_sample.describe()
# Out:
#               Sex           Age        Height        Weight          Rank  \
# count  777.000000  7.770000e+02  7.770000e+02  7.770000e+02  7.770000e+02
# mean     0.513514  2.926302e-16  1.579746e-15 -1.371704e-16  1.463151e-16
# std      0.500139  1.000000e+00  1.000000e+00  1.000000e+00  1.000000e+00
# min      0.000000 -1.730595e+00 -3.069027e+00 -2.490500e+00 -2.294109e+00
# 25%      0.000000 -7.590107e-01 -7.039890e-01 -7.832936e-01 -8.245933e-01
# 50%      1.000000 -3.032292e-02  1.969778e-01  7.030966e-02  6.449227e-01
# 75%      1.000000  6.983649e-01  7.600820e-01  7.342233e-01  6.449227e-01
# max      1.000000  3.370220e+00  2.674637e+00  3.105343e+00  6.449227e-01
#
#        Has_Previous_Medal       Count
# count        7.770000e+02  777.000000
# mean         7.315755e-17    0.000000
# std          1.000000e+00    1.000000
# min         -3.044791e-01   -0.471164
# 25%         -3.044791e-01   -0.471164
# 50%         -3.044791e-01   -0.471164
# 75%         -3.044791e-01   -0.471164
# max          3.280071e+00    5.530389

# %% [markdown]
# - we check Std to be near 1

# %%
Gymnastics_df_5000_sample
# Out:
#                               Name  Sex       Age    Height    Weight  \
# 0                Nstor Abad Sanjun    0  0.455469  0.760082  0.923913
# 1                 Raouf Abdelraouf    0  0.212573  0.760082  0.829068
# 2                       Katja Abel    1  0.941261  0.534840  0.070310
# 3         Andreea Roxana Acatrinei    1 -1.244803 -1.154472 -1.352362
# 4           Jonna Eva-Maj Adlerteg    1 -1.001907 -0.816610 -1.542052
# ..                             ...  ...       ...       ...       ...
# 772  Nataliya Kamilovna Ziganshina    1 -0.759011 -0.478747 -0.688449
# 773            Epke Jan Zonderland    0  0.212573  1.435807  1.398137
# 774                        Zou Kai    0 -0.273219 -0.253506  0.070310
# 775   Roman Volodymyrovych Zozulia    0 -0.030323  0.422219  0.449689
# 776   Roman Volodymyrovych Zozulia    0  0.941261  0.422219  0.449689
#
#             Team Development_Status      Rank  NOC        Games  Season  \
# 0          Spain          Developed  0.644923  ESP  2016 Summer  Summer
# 1          Egypt         Developing -2.294109  EGY  2000 Summer  Summer
# 2        Germany          Developed  0.644923  GER  2008 Summer  Summer
# 3        Romania          Developed  0.644923  ROU  2008 Summer  Summer
# 4         Sweden          Developed  0.644923  SWE  2012 Summer  Summer
# ..           ...                ...       ...  ...          ...     ...
# 772       Russia       Upper-Middle -0.824593  RUS  2004 Summer  Summer
# 773  Netherlands          Developed  0.644923  NED  2008 Summer  Summer
# 774        China       Upper-Middle -0.824593  CHN  2008 Summer  Summer
# 775      Ukraine         Developing -2.294109  UKR  2000 Summer  Summer
# 776      Ukraine         Developing -2.294109  UKR  2004 Summer  Summer
#
#                City       Sport                                     Event  \
# 0    Rio de Janeiro  Gymnastics    Gymnastics Men's Individual All-Around
# 1            Sydney  Gymnastics    Gymnastics Men's Individual All-Around
# 2           Beijing  Gymnastics  Gymnastics Women's Individual All-Around
# 3           Beijing  Gymnastics  Gymnastics Women's Individual All-Around
# 4            London  Gymnastics  Gymnastics Women's Individual All-Around
# ..              ...         ...                                       ...
# 772          Athina  Gymnastics  Gymnastics Women's Individual All-Around
# 773         Beijing  Gymnastics    Gymnastics Men's Individual All-Around
# 774         Beijing  Gymnastics    Gymnastics Men's Individual All-Around
# 775          Sydney  Gymnastics    Gymnastics Men's Individual All-Around
# 776          Athina  Gymnastics    Gymnastics Men's Individual All-Around
#
#      Has_Previous_Medal     Count Medal
# 0             -0.304479 -0.471164   NaN
# 1             -0.304479 -0.471164   NaN
# 2             -0.304479 -0.471164   NaN
# 3             -0.304479 -0.471164   NaN
# 4             -0.304479 -0.471164   NaN
# ..                  ...       ...   ...
# 772           -0.304479 -0.471164   NaN
# 773           -0.304479 -0.471164   NaN
# 774           -0.304479 -0.471164   NaN
# 775           -0.304479 -0.471164   NaN
# 776            3.280071  1.529353   NaN
#
# [777 rows x 17 columns]

# %%
print("isnull count:")
print(Gymnastics_df_5000_sample.isna().sum())
# Out:
# isnull count:
# Name                    0
# Sex                     0
# Age                     0
# Height                  0
# Weight                  0
# Team                    0
# Development_Status      0
# Rank                    0
# NOC                     0
# Games                   0
# Season                  0
# City                    0
# Sport                   0
# Event                   0
# Has_Previous_Medal      0
# Count                   0
# Medal                 747
# dtype: int64

# %% [markdown]
# # test and train data

# %% [markdown]
# - mean and std are near 1 so we can continue
# - frist of all we should which data is train and which is test
# - next step we use classifaction methods and check accuracy and recall and precision

# %% [markdown]
# - i use random.rand that gives me numbers around 0 and 1

# %%
msk = np.random.rand(len(Gymnastics_df_5000_sample)) < 0.8
train = Gymnastics_df_5000_sample[msk]
test = Gymnastics_df_5000_sample[~msk]

# %% [markdown]
# - data is extreme imbalance due to every year only gets 3 medals and there is only 2 sex (5*3)*2 = 30
# - and there is 777 - 747 = 30 so we should oversample or undersample them

# %% [markdown]
# - due to this data i prefer to use oversample to make this extreme imbalance faide

# %%
medal = train[train["Medal"].notna()]
no_medal = train[train["Medal"].isna()]
medal_oversampled = medal.sample(len(no_medal), replace=True, random_state=42)
df_balanced = pd.concat([medal_oversampled, no_medal])
# for shuffle
df_balanced = (
    pd.concat([medal_oversampled, no_medal])
    .sample(frac=1, random_state=42)
    .reset_index(drop=True)
)
df_balanced.to_csv('../data/Generated_data.csv')
df_balanced
# Out:
#                                  Name  Sex       Age    Height    Weight  \
# 0                          Yang Yilin    1 -1.487699 -1.154472 -1.826586
# 1                            Yang Wei    0 -0.273219 -0.028264 -0.024535
# 2     Carly Rae Patterson (-Caldwell)    1 -1.244803 -0.929231 -0.972983
# 3                Simona Amnar (-Tabr)    1 -0.273219 -0.253506 -0.972983
# 4                      Barbara Gasser    1  0.212573  0.534840  0.259999
# ...                               ...  ...       ...       ...       ...
# 1173                  Elisabeth Seitz    1  0.212573  0.196978  0.259999
# 1174                    Olha Teslenko    1 -0.516115 -1.041852 -1.352362
# 1175                    Brooke Walker    1 -0.759011 -0.028264 -0.688449
# 1176                 Julija Kovaliova    1 -0.516115 -0.591368 -0.593604
# 1177                    Igors Vihrovs    0  0.212573  0.534840  0.734223
#
#                Team Development_Status      Rank  NOC        Games  Season  \
# 0             China       Upper-Middle -0.824593  CHN  2008 Summer  Summer
# 1             China       Upper-Middle -0.824593  CHN  2000 Summer  Summer
# 2     United States          Developed  0.644923  USA  2004 Summer  Summer
# 3           Romania          Developed  0.644923  ROU  2000 Summer  Summer
# 4           Austria          Developed  0.644923  AUT  2012 Summer  Summer
# ...             ...                ...       ...  ...          ...     ...
# 1173        Germany          Developed  0.644923  GER  2016 Summer  Summer
# 1174        Ukraine         Developing -2.294109  UKR  2000 Summer  Summer
# 1175      Australia          Developed  0.644923  AUS  2000 Summer  Summer
# 1176      Lithuania          Developed  0.644923  LTU  2000 Summer  Summer
# 1177         Latvia          Developed  0.644923  LAT  2000 Summer  Summer
#
#                 City       Sport                                     Event  \
# 0            Beijing  Gymnastics  Gymnastics Women's Individual All-Around
# 1             Sydney  Gymnastics    Gymnastics Men's Individual All-Around
# 2             Athina  Gymnastics  Gymnastics Women's Individual All-Around
# 3             Sydney  Gymnastics  Gymnastics Women's Individual All-Around
# 4             London  Gymnastics  Gymnastics Women's Individual All-Around
# ...              ...         ...                                       ...
# 1173  Rio de Janeiro  Gymnastics  Gymnastics Women's Individual All-Around
# 1174          Sydney  Gymnastics  Gymnastics Women's Individual All-Around
# 1175          Sydney  Gymnastics  Gymnastics Women's Individual All-Around
# 1176          Sydney  Gymnastics  Gymnastics Women's Individual All-Around
# 1177          Sydney  Gymnastics    Gymnastics Men's Individual All-Around
#
#       Has_Previous_Medal     Count   Medal
# 0              -0.304479 -0.471164  Bronze
# 1              -0.304479 -0.471164  Silver
# 2              -0.304479 -0.471164    Gold
# 3               3.280071 -0.471164    Gold
# 4              -0.304479 -0.471164     NaN
# ...                  ...       ...     ...
# 1173           -0.304479  1.529353     NaN
# 1174           -0.304479 -0.471164     NaN
# 1175           -0.304479 -0.471164     NaN
# 1176           -0.304479 -0.471164     NaN
# 1177           -0.304479 -0.471164     NaN
#
# [1178 rows x 17 columns]

# %% [markdown]
# - to check if there any problem

# %%
df_balanced.describe()
# Out:
#                Sex          Age       Height       Weight         Rank  \
# count  1178.000000  1178.000000  1178.000000  1178.000000  1178.000000
# mean      0.531409    -0.053004    -0.069087    -0.111490    -0.032452
# std       0.499224     0.920717     0.956827     0.952580     0.958466
# min       0.000000    -1.730595    -2.731164    -2.300810    -2.294109
# 25%       0.000000    -0.759011    -0.703989    -0.783294    -0.824593
# 50%       1.000000    -0.273219    -0.028264    -0.024535     0.644923
# 75%       1.000000     0.698365     0.534840     0.639378     0.644923
# max       1.000000     3.370220     2.674637     3.105343     0.644923
#
#        Has_Previous_Medal        Count
# count         1178.000000  1178.000000
# mean             0.431905     0.157182
# std              1.448836     1.165918
# min             -0.304479    -0.471164
# 25%             -0.304479    -0.471164
# 50%             -0.304479    -0.471164
# 75%             -0.304479     1.529353
# max              3.280071     5.530389

# %% [markdown]
# - Target is a athletic can win or no so we create a column that is our goal
# - also we select the features we need for models

# %%
df_balanced["Target"] = df_balanced["Medal"].notna().astype(int)
test["Target"] = test["Medal"].notna().astype(int)

# Feature columns
features = [
    "Age",
    "Height",
    "Weight",
    "Sex",
    "Rank",
    "Has_Previous_Medal",
    "Count"
]

X_train = df_balanced[features]
y_train = df_balanced["Target"]

X_test = test[features]
y_test = test["Target"]
# Out:
# C:\Users\aamyr\AppData\Local\Temp\ipykernel_15012\3106028675.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test["Target"] = test["Medal"].notna().astype(int)

# %%
X_train , y_train , X_test , y_test
# Out:
# (           Age    Height    Weight  Sex      Rank  Has_Previous_Medal  \
#  0    -1.487699 -1.154472 -1.826586    1 -0.824593           -0.304479
#  1    -0.273219 -0.028264 -0.024535    0 -0.824593           -0.304479
#  2    -1.244803 -0.929231 -0.972983    1  0.644923           -0.304479
#  3    -0.273219 -0.253506 -0.972983    1  0.644923            3.280071
#  4     0.212573  0.534840  0.259999    1  0.644923           -0.304479
#  ...        ...       ...       ...  ...       ...                 ...
#  1173  0.212573  0.196978  0.259999    1  0.644923           -0.304479
#  1174 -0.516115 -1.041852 -1.352362    1 -2.294109           -0.304479
#  1175 -0.759011 -0.028264 -0.688449    1  0.644923           -0.304479
#  1176 -0.516115 -0.591368 -0.593604    1  0.644923           -0.304479
#  1177  0.212573  0.534840  0.734223    0  0.644923           -0.304479
#
#           Count
#  0    -0.471164
#  1    -0.471164
#  2    -0.471164
#  3    -0.471164
#  4    -0.471164
#  ...        ...
#  1173  1.529353
#  1174 -0.471164
#  1175 -0.471164
#  1176 -0.471164
#  1177 -0.471164
#
#  [1178 rows x 7 columns],
#  0       1
#  1       1
#  2       1
#  3       1
#  4       0
#         ..
#  1173    0
#  1174    0
#  1175    0
#  1176    0
#  1177    0
#  Name: Target, Length: 1178, dtype: int64,
#            Age    Height    Weight  Sex      Rank  Has_Previous_Medal     Count
#  1    0.212573  0.760082  0.829068    0 -2.294109           -0.304479 -0.471164
#  6   -1.001907 -0.140885 -0.403914    1 -2.294109           -0.304479 -0.471164
#  7   -0.030323  0.196978 -0.024535    0 -2.294109           -0.304479 -0.471164
#  11  -0.516115 -0.591368  0.449689    1 -0.824593           -0.304479 -0.471164
#  14   1.669949  0.647461  0.734223    0  0.644923           -0.304479  1.529353
#  ..        ...       ...       ...  ...       ...                 ...       ...
#  757  0.698365  0.872703  0.449689    0  0.644923           -0.304479 -0.471164
#  759  2.398636  0.309599  0.734223    0  0.644923            3.280071  1.529353
#  764 -0.030323 -0.703989 -1.067828    1 -0.824593            3.280071  1.529353
#  767 -0.759011 -0.478747 -0.783294    1 -0.824593           -0.304479 -0.471164
#  774 -0.273219 -0.253506  0.070310    0 -0.824593           -0.304479 -0.471164
#
#  [163 rows x 7 columns],
#  1      0
#  6      0
#  7      0
#  11     0
#  14     0
#        ..
#  757    0
#  759    0
#  764    0
#  767    0
#  774    0
#  Name: Target, Length: 163, dtype: int64)

# %% [markdown]
# - i want to develop types of methods then we'll watch which is better

# %% [markdown]
# # KNN

# %%
knn = KNeighborsClassifier(
    n_neighbors=5,      
    metric="euclidean", # فاصله
    weights="distance"  # weighted KNN (imbalance)
)

knn.fit(X_train, y_train)
y_pred = knn.predict(X_test)

# %% [markdown]
# - Precision=TP/TP+FP
# - Recall=TP/TP+FN
# - F1-score=2×Precision×Recall/Precision+Recall

# %%
print("Confusion Matrix:")
print(confusion_matrix(y_test, y_pred))

print("\nClassification Report:")
print(classification_report(y_test, y_pred))

print("F1:", f1_score(y_test, y_pred))
print("Precision:", precision_score(y_test, y_pred))
print("Recall:", recall_score(y_test, y_pred))
# Out:
# Confusion Matrix:
# [[142  16]
#  [  5   0]]
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.97      0.90      0.93       158
#            1       0.00      0.00      0.00         5
#
#     accuracy                           0.87       163
#    macro avg       0.48      0.45      0.47       163
# weighted avg       0.94      0.87      0.90       163
#
# F1: 0.0
# Precision: 0.0
# Recall: 0.0

# %% [markdown]
# # ID3

# %%
dt = DecisionTreeClassifier(
    criterion='entropy',
    max_depth=5,
    class_weight='balanced',
    random_state=42
)

dt.fit(X_train, y_train)
y_pred_dt = dt.predict(X_test)

# %% [markdown]
# - Precision=TP/TP+FP
# - Recall=TP/TP+FN
# - F1-score=2×Precision×Recall/Precision+Recall

# %%
print("Confusion Matrix:")
print(confusion_matrix(y_test, y_pred_dt))

print("\nClassification Report:")
print(classification_report(y_test, y_pred_dt))

print("F1:", f1_score(y_test, y_pred_dt))
print("Precision:", precision_score(y_test, y_pred_dt))
print("Recall:", recall_score(y_test, y_pred_dt))
# Out:
# Confusion Matrix:
# [[86 72]
#  [ 4  1]]
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.96      0.54      0.69       158
#            1       0.01      0.20      0.03         5
#
#     accuracy                           0.53       163
#    macro avg       0.48      0.37      0.36       163
# weighted avg       0.93      0.53      0.67       163
#
# F1: 0.02564102564102564
# Precision: 0.0136986301369863
# Recall: 0.2

# %% [markdown]
# # GaussianNB
# - P(C∣X)=(P(X∣C)⋅P(C))/P(X)

# %%
gnb = GaussianNB()
gnb.fit(X_train, y_train)
y_pred_gnb = gnb.predict(X_test)

# %% [markdown]
# - Precision=TP/TP+FP
# - Recall=TP/TP+FN
# - F1-score=2×Precision×Recall/Precision+Recall

# %%
print("Confusion Matrix:")
print(confusion_matrix(y_test, y_pred_gnb))

print("\nClassification Report:")
print(classification_report(y_test, y_pred_gnb))

print("F1:", f1_score(y_test, y_pred_gnb))
print("Precision:", precision_score(y_test, y_pred_gnb))
print("Recall:", recall_score(y_test, y_pred_gnb))
# Out:
# Confusion Matrix:
# [[135  23]
#  [  4   1]]
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.97      0.85      0.91       158
#            1       0.04      0.20      0.07         5
#
#     accuracy                           0.83       163
#    macro avg       0.51      0.53      0.49       163
# weighted avg       0.94      0.83      0.88       163
#
# F1: 0.06896551724137931
# Precision: 0.041666666666666664
# Recall: 0.2

# %% [markdown]
# - based on data models act differentlly often GaussianNB is better than others

# %% [markdown]
# # Clustering

# %% [markdown]
# - back to basic algorithm in clustering (K-means)

# %%
features = ["Age", "Height", "Weight", "Sex", "Rank", "Has_Previous_Medal", "Count"]
X = Gymnastics_df_5000_sample[features]

# K-Means with 2 clusters (Medal vs No Medal)
kmeans = KMeans(n_clusters=2, random_state=42, n_init=10)
clusters = kmeans.fit_predict(X)

Gymnastics_df_5000_sample["Cluster"] = clusters

# %%
Gymnastics_df_5000_sample["Target"] = Gymnastics_df_5000_sample["Medal"].notna().astype(int)

# Crosstab to see which cluster has more medal winners
cluster_vs_medal = pd.crosstab(
    Gymnastics_df_5000_sample["Cluster"],
    Gymnastics_df_5000_sample["Target"],
    rownames=["Cluster"],
    colnames=["Has Medal"]
)

print(cluster_vs_medal)
# Out:
# Has Medal    0   1
# Cluster
# 0          352  14
# 1          395  16

# %%
cluster_vs_medal_pct = cluster_vs_medal.div(cluster_vs_medal.sum(axis=1), axis=0) * 100
print(cluster_vs_medal_pct)
# Out:
# Has Medal          0         1
# Cluster
# 0          96.174863  3.825137
# 1          96.107056  3.892944

# %%
pca = PCA(n_components=2)
X_pca = pca.fit_transform(X)

plt.figure(figsize=(8,6))
# Loop through clusters
for cluster_id in Gymnastics_df_5000_sample["Cluster"].unique():
    cluster_data = X_pca[Gymnastics_df_5000_sample["Cluster"] == cluster_id]
    medal_flags = Gymnastics_df_5000_sample["Target"][Gymnastics_df_5000_sample["Cluster"] == cluster_id]

    # Plot medal winners with 'o' and non-medal with 'x'
    plt.scatter(
        cluster_data[medal_flags==0,0],
        cluster_data[medal_flags==0,1],
        label=f'Cluster {cluster_id} - No Medal',
        marker='x',
        alpha=0.6
    )
    plt.scatter(
        cluster_data[medal_flags==1,0],
        cluster_data[medal_flags==1,1],
        label=f'Cluster {cluster_id} - Medal',
        marker='o',
        alpha=0.8
    )

plt.xlabel("PCA 1")
plt.ylabel("PCA 2")
plt.title("K-Means Clusters with Medal Distribution")
plt.legend()
plt.show()

# %% [markdown]
# - DBSCAN

# %%
dbscan = DBSCAN(
    eps=2,        # distance threshold (tune this!)
    min_samples=15  # minimum points to form a cluster
)

clusters = dbscan.fit_predict(X)

Gymnastics_df_5000_sample["Cluster_DBSCAN"] = clusters

# %%
Gymnastics_df_5000_sample["Target"] = (
    Gymnastics_df_5000_sample["Medal"].notna().astype(int)
)

cluster_vs_medal = pd.crosstab(
    Gymnastics_df_5000_sample["Cluster_DBSCAN"],
    Gymnastics_df_5000_sample["Target"]
)

print(cluster_vs_medal)
# Out:
# Target            0   1
# Cluster_DBSCAN
# -1               42   5
#  0              584  17
#  1               94   4
#  2               27   4

# %%
cluster_vs_medal_pct = cluster_vs_medal.div(
    cluster_vs_medal.sum(axis=1), axis=0
) * 100

print(cluster_vs_medal_pct)
# Out:
# Target                  0          1
# Cluster_DBSCAN
# -1              89.361702  10.638298
#  0              97.171381   2.828619
#  1              95.918367   4.081633
#  2              87.096774  12.903226

# %%
clusters = Gymnastics_df_5000_sample["Cluster_DBSCAN"].values
unique_clusters = np.unique(clusters)

pca = PCA(n_components=2)
X_pca = pca.fit_transform(X)

plt.figure(figsize=(8,6))
for cluster_id in unique_clusters:
    mask = clusters == cluster_id

    if cluster_id == -1:
        label = "Noise"
        marker = 'x'
        alpha = 0.4
    else:
        label = f"Cluster {cluster_id}"
        marker = 'o'
        alpha = 0.7

    plt.scatter(
        X_pca[mask, 0],
        X_pca[mask, 1],
        label=label,
        marker=marker,
        alpha=alpha
    )
plt.xlabel("PCA 1")
plt.ylabel("PCA 2")
plt.title("DBSCAN Clusters (PCA Projection)")
plt.show()
